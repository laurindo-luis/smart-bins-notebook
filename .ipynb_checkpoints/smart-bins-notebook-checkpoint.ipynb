# %%
import pandas as pd
import matplotlib
import matplotlib.pyplot as plt

matplotlib.rc('xtick', labelsize=15) 
matplotlib.rc('ytick', labelsize=15)

# %%
dfSmartBins_1 = pd.read_csv('smart-bins_1.csv')
dfSmartBins_1['id'] = range(1, len(dfSmartBins_1.index) + 1)
dfSmartBins_1.set_index('id')

dfSmartBins_2 = pd.read_csv('smart-bins_2.csv')
dfSmartBins_2['id'] = range(len(dfSmartBins_1.index) + 1, len(dfSmartBins_1.index) + len(dfSmartBins_2.index) + 1)
dfSmartBins_2.set_index('id')

dfSmartBins = pd.concat([dfSmartBins_1, dfSmartBins_2], axis=0)
dfSmartBins = dfSmartBins.set_index('id')
dfSmartBins
# Out:
#        batteryHealth                       binId  binStatus  currentFillLevel  \
# id
# 1                 95   CleanCUBE-A1905081905AA07  Half Full                55
# 2                100  CleanFLEX-FB2000001911AA89       Full                92
# 3                 10  CleanFLEX-FB1000001906AA19       Full               100
# 4                 10  CleanFLEX-FB1000001906AA18        Low                14
# 5                 95   CleanCUBE-A1905081905AA02        Low                 0
# ...              ...                         ...        ...               ...
# 38796             10  CleanFLEX-FB2000002008AC19        Low                18
# 38797             95  CleanFLEX-FB2000002005AB64       Full                77
# 38798             95  CleanFLEX-FB2000002005AB66        Low                12
# 38799             95   CleanCUBE-A1811211812AA04        Low                 0
# 38800            100   CleanCUBE-D1905281906AA03  Half Full                42
#
#                       latLong            timesTamp
# id
# 1                         NaN  2021-09-21 13:00:03
# 2                         NaN  2021-09-21 13:00:03
# 3                         NaN  2021-09-21 13:00:03
# 4                         NaN  2021-09-21 13:00:03
# 5                         NaN  2021-09-21 13:00:03
# ...                       ...                  ...
# 38796  -33.920289, 151.257056  2021-10-22 11:00:12
# 38797  -33.920816, 151.257022  2021-10-22 11:00:12
# 38798  -33.920944, 151.257001  2021-10-22 11:00:12
# 38799                     NaN  2021-01-23 04:00:03
# 38800                     NaN  2021-01-23 04:00:03
#
# [38800 rows x 6 columns]

# %% [markdown]
# # Data Cleaning

# %%
dfSmartBins = dfSmartBins[~dfSmartBins.isnull().T.any()]
dfSmartBins = dfSmartBins[~(dfSmartBins.timesTamp < '2021-09-22')]
dfSmartBins
# Out:
#        batteryHealth                       binId  binStatus  currentFillLevel  \
# id
# 554              100  CleanFLEX-FB2000002008AC02  Half Full                46
# 555              100  CleanFLEX-FB2000002008AC03  Half Full                49
# 556              100  CleanFLEX-FB2000002008AC05  Half Full                43
# 557              100  CleanFLEX-FB2000002008AC01        Low                28
# 560              100  CleanFLEX-FB2000002008AC12        Low                16
# ...              ...                         ...        ...               ...
# 38794             10  CleanFLEX-FB2000002008AC06       Full                88
# 38795             10  CleanFLEX-FB2000002008AC20        Low                17
# 38796             10  CleanFLEX-FB2000002008AC19        Low                18
# 38797             95  CleanFLEX-FB2000002005AB64       Full                77
# 38798             95  CleanFLEX-FB2000002005AB66        Low                12
#
#                       latLong            timesTamp
# id
# 554    -33.920227, 151.257692  2021-09-22 00:00:04
# 555     -33.918951, 151.25847  2021-09-22 00:00:04
# 556    -33.919505, 151.257857  2021-09-22 00:00:04
# 557    -33.919135, 151.258104  2021-09-22 00:00:04
# 560    -33.919727, 151.257213  2021-09-22 00:00:04
# ...                       ...                  ...
# 38794   -33.91947, 151.257542  2021-10-22 11:00:12
# 38795  -33.920372, 151.257036  2021-10-22 11:00:12
# 38796  -33.920289, 151.257056  2021-10-22 11:00:12
# 38797  -33.920816, 151.257022  2021-10-22 11:00:12
# 38798  -33.920944, 151.257001  2021-10-22 11:00:12
#
# [22950 rows x 6 columns]

# %% [markdown]
# ## Duplicados

# %%
dfSmartBins[dfSmartBins.duplicated()]
# Out:
#        batteryHealth                       binId  binStatus  currentFillLevel  \
# id
# 6802             100  CleanFLEX-FB2000002008AC02  Half Full                52
# 6803             100  CleanFLEX-FB2000002008AC01        Low                23
# 6804             100  CleanFLEX-FB2000002008AC03        Low                 7
# 6809             100  CleanFLEX-FB2000002008AC17  Half Full                48
# 6810             100  CleanFLEX-FB2000002008AC05        Low                11
# ...              ...                         ...        ...               ...
# 38794             10  CleanFLEX-FB2000002008AC06       Full                88
# 38795             10  CleanFLEX-FB2000002008AC20        Low                17
# 38796             10  CleanFLEX-FB2000002008AC19        Low                18
# 38797             95  CleanFLEX-FB2000002005AB64       Full                77
# 38798             95  CleanFLEX-FB2000002005AB66        Low                12
#
#                       latLong            timesTamp
# id
# 6802   -33.920227, 151.257692  2021-09-27 04:00:08
# 6803   -33.919135, 151.258104  2021-09-27 04:00:08
# 6804    -33.918951, 151.25847  2021-09-27 04:00:08
# 6809    -33.91947, 151.257542  2021-09-27 04:00:08
# 6810   -33.919505, 151.257857  2021-09-27 04:00:08
# ...                       ...                  ...
# 38794   -33.91947, 151.257542  2021-10-22 11:00:12
# 38795  -33.920372, 151.257036  2021-10-22 11:00:12
# 38796  -33.920289, 151.257056  2021-10-22 11:00:12
# 38797  -33.920816, 151.257022  2021-10-22 11:00:12
# 38798  -33.920944, 151.257001  2021-10-22 11:00:12
#
# [450 rows x 6 columns]

# %%
dfSmartBins[(dfSmartBins.binId == 'CleanFLEX-FB2000002005AB66') & (dfSmartBins.timesTamp == '2021-10-06 20:00:04')]
# Out:
#        batteryHealth                       binId binStatus  currentFillLevel  \
# id
# 18198             95  CleanFLEX-FB2000002005AB66       Low                19
# 18248             95  CleanFLEX-FB2000002005AB66       Low                19
#
#                       latLong            timesTamp
# id
# 18198  -33.920944, 151.257001  2021-10-06 20:00:04
# 18248  -33.920944, 151.257001  2021-10-06 20:00:04

# %%
dfSmartBins = dfSmartBins[~dfSmartBins.duplicated()]
dfSmartBins
# Out:
#        batteryHealth                       binId  binStatus  currentFillLevel  \
# id
# 554              100  CleanFLEX-FB2000002008AC02  Half Full                46
# 555              100  CleanFLEX-FB2000002008AC03  Half Full                49
# 556              100  CleanFLEX-FB2000002008AC05  Half Full                43
# 557              100  CleanFLEX-FB2000002008AC01        Low                28
# 560              100  CleanFLEX-FB2000002008AC12        Low                16
# ...              ...                         ...        ...               ...
# 38743             10  CleanFLEX-FB2000002008AC06       Full                88
# 38745             95  CleanFLEX-FB2000002005AB64       Full                76
# 38746             10  CleanFLEX-FB2000002008AC20        Low                17
# 38747             10  CleanFLEX-FB2000002008AC19        Low                18
# 38748             95  CleanFLEX-FB2000002005AB66        Low                11
#
#                       latLong            timesTamp
# id
# 554    -33.920227, 151.257692  2021-09-22 00:00:04
# 555     -33.918951, 151.25847  2021-09-22 00:00:04
# 556    -33.919505, 151.257857  2021-09-22 00:00:04
# 557    -33.919135, 151.258104  2021-09-22 00:00:04
# 560    -33.919727, 151.257213  2021-09-22 00:00:04
# ...                       ...                  ...
# 38743   -33.91947, 151.257542  2021-10-22 10:00:05
# 38745  -33.920816, 151.257022  2021-10-22 10:00:05
# 38746  -33.920372, 151.257036  2021-10-22 10:00:05
# 38747  -33.920289, 151.257056  2021-10-22 10:00:05
# 38748  -33.920944, 151.257001  2021-10-22 10:00:05
#
# [22500 rows x 6 columns]

# %%
dfSmartBins[(dfSmartBins.binId == 'CleanFLEX-FB2000002005AB66') & (dfSmartBins.timesTamp == '2021-10-06 20:00:04')]
# Out:
#        batteryHealth                       binId binStatus  currentFillLevel  \
# id
# 18198             95  CleanFLEX-FB2000002005AB66       Low                19
#
#                       latLong            timesTamp
# id
# 18198  -33.920944, 151.257001  2021-10-06 20:00:04

# %%
dfSmartBins = dfSmartBins.drop(dfSmartBins[dfSmartBins.timesTamp > '2021-10-14'].index, axis=0)
dfSmartBins
# Out:
#        batteryHealth                       binId  binStatus  currentFillLevel  \
# id
# 554              100  CleanFLEX-FB2000002008AC02  Half Full                46
# 555              100  CleanFLEX-FB2000002008AC03  Half Full                49
# 556              100  CleanFLEX-FB2000002008AC05  Half Full                43
# 557              100  CleanFLEX-FB2000002008AC01        Low                28
# 560              100  CleanFLEX-FB2000002008AC12        Low                16
# ...              ...                         ...        ...               ...
# 29194             10  CleanFLEX-FB2000002008AC19        Low                18
# 29195             10  CleanFLEX-FB2000002008AC20        Low                17
# 29196             10  CleanFLEX-FB2000002008AC13  Half Full                41
# 29197             95  CleanFLEX-FB2000002005AB64  Half Full                64
# 29198             95  CleanFLEX-FB2000002005AB66        Low                 7
#
#                       latLong            timesTamp
# id
# 554    -33.920227, 151.257692  2021-09-22 00:00:04
# 555     -33.918951, 151.25847  2021-09-22 00:00:04
# 556    -33.919505, 151.257857  2021-09-22 00:00:04
# 557    -33.919135, 151.258104  2021-09-22 00:00:04
# 560    -33.919727, 151.257213  2021-09-22 00:00:04
# ...                       ...                  ...
# 29194  -33.920289, 151.257056  2021-10-13 23:00:05
# 29195  -33.920372, 151.257036  2021-10-13 23:00:05
# 29196  -33.920034, 151.257165  2021-10-13 23:00:05
# 29197  -33.920816, 151.257022  2021-10-13 23:00:05
# 29198  -33.920944, 151.257001  2021-10-13 23:00:05
#
# [15210 rows x 6 columns]

# %% [markdown]
# ## Teste

# %%
#df = dfSmartBins[(dfSmartBins.binId == 'CleanFLEX-FB2000002008AC07') & ((dfSmartBins.timesTamp >= '2021-09-30 00:00:00') & (dfSmartBins.timesTamp <= '2021-09-30 23:59:59'))]
#df = dfSmartBins[(dfSmartBins.binId == 'CleanFLEX-FB2000002008AC07')]
#df

# %% [markdown]
# # Análises de Dados

# %%
dfSmartBins
# Out:
#        batteryHealth                       binId  binStatus  currentFillLevel  \
# id
# 554              100  CleanFLEX-FB2000002008AC02  Half Full                46
# 555              100  CleanFLEX-FB2000002008AC03  Half Full                49
# 556              100  CleanFLEX-FB2000002008AC05  Half Full                43
# 557              100  CleanFLEX-FB2000002008AC01        Low                28
# 560              100  CleanFLEX-FB2000002008AC12        Low                16
# ...              ...                         ...        ...               ...
# 29194             10  CleanFLEX-FB2000002008AC19        Low                18
# 29195             10  CleanFLEX-FB2000002008AC20        Low                17
# 29196             10  CleanFLEX-FB2000002008AC13  Half Full                41
# 29197             95  CleanFLEX-FB2000002005AB64  Half Full                64
# 29198             95  CleanFLEX-FB2000002005AB66        Low                 7
#
#                       latLong            timesTamp
# id
# 554    -33.920227, 151.257692  2021-09-22 00:00:04
# 555     -33.918951, 151.25847  2021-09-22 00:00:04
# 556    -33.919505, 151.257857  2021-09-22 00:00:04
# 557    -33.919135, 151.258104  2021-09-22 00:00:04
# 560    -33.919727, 151.257213  2021-09-22 00:00:04
# ...                       ...                  ...
# 29194  -33.920289, 151.257056  2021-10-13 23:00:05
# 29195  -33.920372, 151.257036  2021-10-13 23:00:05
# 29196  -33.920034, 151.257165  2021-10-13 23:00:05
# 29197  -33.920816, 151.257022  2021-10-13 23:00:05
# 29198  -33.920944, 151.257001  2021-10-13 23:00:05
#
# [15210 rows x 6 columns]

# %% [markdown]
# ## Buscando lixeiras

# %%
bins = set()

for bin in dfSmartBins.binId.values:
    bins.add(bin)
bins = list(bins)

# %% [markdown]
# ## Tempo médio para cada lixeira chegar ao nível Full

# %%
def tempo_medio_full(df):
    tempo_hora = 0
    tempo = []

    if len(df) > 0:
    
        for status in df.currentFillLevel.values:
            if status < 70:
                tempo_hora += 1
            elif tempo_hora > 0:
                tempo.append(tempo_hora)
                tempo_hora = 0
    if (len(tempo) > 0):
        return (sum(tempo) / len(tempo)) / 24
    return 0

list_tempo_medio_full = {}
for bin in bins:
    df = dfSmartBins[dfSmartBins.binId == bin]
    list_tempo_medio_full[bin] = tempo_medio_full(df)

# %%
plt.figure(figsize=(20, 7))
plt.bar(list_tempo_medio_full.keys(), list_tempo_medio_full.values())
plt.xticks(rotation=90)
plt.title('Tempo médio para cada lixeira chegar ao nível full', fontsize=20)
plt.xlabel('Lixeira', fontsize=20)
plt.ylabel('Tempo (dias)', fontsize=20)
plt.show()

# %% [markdown]
# ## Qual tempo médio que cada lixeira leva para ser coletada?

# %%
def is_coleta(old_level, level):
    diferenca = old_level - level
    return True if (diferenca >= 20) else False

def tempo_coleta(df):
    tempo_hora = 0
    tempo = []

    if len(df) > 0:
            
        old_status = df.currentFillLevel.values[0]
    
        for status in df.currentFillLevel.values[1:]:
            if (is_coleta(old_status, status)):
                tempo.append(tempo_hora + 1)
                tempo_hora = 0
                old_status = status
            else:
                tempo_hora += 1
                old_status = status
    if (len(tempo) > 0):
        return (sum(tempo) / len(tempo)) / 24
    return 0
                    
tempo_medio_coleta = {}
for bin in bins:
    df = dfSmartBins[dfSmartBins.binId == bin]
    tempo_medio_coleta[bin] = tempo_coleta(df)

# %%
plt.figure(figsize=(20, 7))
plt.bar(tempo_medio_coleta.keys(), tempo_medio_coleta.values())
plt.xticks(rotation=90)
plt.title('Tempo médio que cada lixeira leva para ser coletada', fontsize=20)
plt.xlabel('Lixeira', fontsize=20)
plt.ylabel('Tempo (dias)', fontsize=20)
plt.show()

# %% [markdown]
# ## Quantas coletas é realizada em cada lixeira a cada dia?

# %%
timesTamps = set()
for time in dfSmartBins.timesTamp.values:
    date = time.split(' ')[0]
    timesTamps.add(date)
    
timesTamps = sorted(list(timesTamps))

# %%
def quantidade_coleta(df, dias):
    result = {'dia': [], 'quantidade_coleta': []}
    for dia in dias:
        quantidade = 0
        dfResult = df[(df.timesTamp >= dia+' 00:00:00') & (df.timesTamp <= dia+' 23:59:00')]
        
        if len(dfResult) > 0:
            
            old_status = dfResult.currentFillLevel.values[0]
            for status in dfResult.currentFillLevel.values[1:]:
                if (is_coleta(old_status, status)):
                    quantidade += 1
                old_status = status 
        
        result['dia'].append(dia)
        result['quantidade_coleta'].append(quantidade)
    return result   

result = {}
for bin in bins:
    df = dfSmartBins[dfSmartBins.binId == bin]
    result[bin] = quantidade_coleta(df, timesTamps)

# %%
df_dados = pd.DataFrame(columns=('bin', 'dia', 'quantidade_coleta'))
for bin in result.keys():
    dias = result[bin].get('dia')
    for d in range(len(dias)):
        dia = dias[d]
        df_dados = df_dados.append({
            'bin': bin,
            'dia': dia,
            'quantidade_coleta': result[bin].get('quantidade_coleta')[d]
        }, ignore_index=True)
    
df_dados
# Out:
#                             bin         dia quantidade_coleta
# 0    CleanFLEX-FB2000002008AC03  2021-09-22                 2
# 1    CleanFLEX-FB2000002008AC03  2021-09-23                 2
# 2    CleanFLEX-FB2000002008AC03  2021-09-24                 2
# 3    CleanFLEX-FB2000002008AC03  2021-09-25                 1
# 4    CleanFLEX-FB2000002008AC03  2021-09-26                 0
# ..                          ...         ...               ...
# 655  CleanFLEX-FB2000002005AB70  2021-10-09                 1
# 656  CleanFLEX-FB2000002005AB70  2021-10-10                 0
# 657  CleanFLEX-FB2000002005AB70  2021-10-11                 0
# 658  CleanFLEX-FB2000002005AB70  2021-10-12                 0
# 659  CleanFLEX-FB2000002005AB70  2021-10-13                 0
#
# [660 rows x 3 columns]

# %%
import seaborn as sns

sns.set(rc={'figure.figsize': (20, 10)})
sns.heatmap(df_dados.pivot_table(index='bin', columns='dia', values='quantidade_coleta'), annot=True)

# %% [markdown]
# ## Quais dias houve o maior número de coleta?

# %%
df_dados
# Out:
#                             bin         dia quantidade_coleta
# 0    CleanFLEX-FB2000002008AC03  2021-09-22                 2
# 1    CleanFLEX-FB2000002008AC03  2021-09-23                 2
# 2    CleanFLEX-FB2000002008AC03  2021-09-24                 2
# 3    CleanFLEX-FB2000002008AC03  2021-09-25                 1
# 4    CleanFLEX-FB2000002008AC03  2021-09-26                 0
# ..                          ...         ...               ...
# 655  CleanFLEX-FB2000002005AB70  2021-10-09                 1
# 656  CleanFLEX-FB2000002005AB70  2021-10-10                 0
# 657  CleanFLEX-FB2000002005AB70  2021-10-11                 0
# 658  CleanFLEX-FB2000002005AB70  2021-10-12                 0
# 659  CleanFLEX-FB2000002005AB70  2021-10-13                 0
#
# [660 rows x 3 columns]

# %%
dados_grafico = df_dados[['dia', 'quantidade_coleta']].groupby('dia').sum()
plt.bar(dados_grafico.index, dados_grafico.quantidade_coleta)
plt.xticks(rotation=90)
plt.title('Quantidade de coleta realizada por dia', fontsize=20)
plt.xlabel('Dia', fontsize=20)
plt.ylabel('Quantidade de coleta', fontsize=20)
plt.show()

# %% [markdown]
# # ARIMA

# %%
import warnings
warnings.filterwarnings("ignore")

# %%
from pandas.plotting import autocorrelation_plot

dfSmartBin = dfSmartBins[dfSmartBins.binId == 'CleanFLEX-FB2000002008AC12']
series = dfSmartBin[['timesTamp', 'currentFillLevel']].set_index('timesTamp')
series
# Out:
#                      currentFillLevel
# timesTamp
# 2021-09-22 00:00:04                16
# 2021-09-22 01:00:05                44
# 2021-09-22 02:00:05                61
# 2021-09-22 03:00:05                 0
# 2021-09-22 04:00:05                 3
# ...                               ...
# 2021-10-13 19:00:05                 3
# 2021-10-13 20:00:05                 3
# 2021-10-13 21:00:05                 3
# 2021-10-13 22:00:04                 3
# 2021-10-13 23:00:05                 3
#
# [507 rows x 1 columns]

# %%
from statsmodels.graphics.tsaplots import plot_acf
from statsmodels.graphics.tsaplots import plot_pacf

# %%
plot_acf(series, lags=40)

# %%
plot_pacf(series, lags=40)

# %%
from statsmodels.tsa.arima.model import ARIMA

model = ARIMA(series, order=(2, 0, 0))
model_fit = model.fit()
model_fit.predict()
# Out:
# /home/luis/.local/lib/python3.8/site-packages/statsmodels/tsa/base/tsa_model.py:593: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   warnings.warn('A date index has been provided, but it has no'
# /home/luis/.local/lib/python3.8/site-packages/statsmodels/tsa/base/tsa_model.py:593: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   warnings.warn('A date index has been provided, but it has no'
# /home/luis/.local/lib/python3.8/site-packages/statsmodels/tsa/base/tsa_model.py:593: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   warnings.warn('A date index has been provided, but it has no'
# timesTamp
# 2021-09-22 00:00:04    22.842550
# 2021-09-22 01:00:05    16.562975
# 2021-09-22 02:00:05    43.510564
# 2021-09-22 03:00:05    58.521057
# 2021-09-22 04:00:05    -0.937830
#                          ...
# 2021-10-13 19:00:05     4.710352
# 2021-10-13 20:00:05     4.710352
# 2021-10-13 21:00:05     4.710352
# 2021-10-13 22:00:04     4.710352
# 2021-10-13 23:00:05     4.710352
# Name: predicted_mean, Length: 507, dtype: float64

# %%
model_fit.forecast(2000)
# Out:
# /home/luis/.local/lib/python3.8/site-packages/statsmodels/tsa/base/tsa_model.py:390: ValueWarning: No supported index is available. Prediction results will be given with an integer index beginning at `start`.
#   warnings.warn('No supported index is available.'
# 507      4.710352
# 508      6.354780
# 509      7.854323
# 510      9.217707
# 511     10.457084
#           ...
# 2502    22.842550
# 2503    22.842550
# 2504    22.842550
# 2505    22.842550
# 2506    22.842550
# Name: predicted_mean, Length: 2000, dtype: float64
